# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/PRODUTOS.xlsx")

# %%
df = df.rename(columns={'Diferença total do preço de mercado VS oque cotaram para a empresa': 'Valor total que estão cobrando a mais comparado ao preço de mercado'})

# %%
df = df.rename(columns={'EXPECTATIVA DE VALOR COMPRANDO O PRODUTO':'EXPECTATIVA DE GASTO AO COMPRAR O PRODUTO NA QUANTIDADE NECESSÁRIA COM BASE NO VALOR DE MERCADO'})

# %%
df.head()
# Out:
#   ITEM                                 DESCRIÇÃO  QUANTIDADE  \
# 0    1          CÂMERA IP VIPC 1230 G2 INTELBRAS         5.0
# 1    2  VBOX 1100-CAIXA DE PASSAGEM PARA CÂMERAS         5.0
# 2    3             SWITCH POE 8 PORTAS INTELBRAS         1.0
# 3    4             SWITCH POE 4 PORTAS INTELBRAS         1.0
# 4    5           CABO DE REDE CAT6 LANDUTTI 300M         2.0
#
#   VALOR QUE COBRARAM  VALOR DE MERCADO  \
# 0            1658.95            300.00
# 1             158.65              9.00
# 2             968.75            899.99
# 3              649.8            450.00
# 4            2593.95           1712.00
#
#    EXPECTATIVA DE GASTO AO COMPRAR O PRODUTO NA QUANTIDADE NECESSÁRIA COM BASE NO VALOR DE MERCADO  \
# 0                                             1500.0
# 1                                               50.0
# 2                                              940.0
# 3                                              468.0
# ...

# %%
df['Diferença de preço entre os produtos'] = df["VALOR QUE COBRARAM"] - df["EXPECTATIVA DE VALOR COMPRANDO O PRODUTO"]

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

ax = df_plot.set_index('ITEM_DESC')[['VALOR QUE\nCOBRARAM', 'EXPECTATIVA DE GASTO AO COMPRAR O PRODUTO\nNA QUANTIDADE NECESSÁRIA COM BASE NO VALOR\nDE MERCADO', 'Valor total que estão\ncobrando a mais\ncomparado ao preço de mercado']].plot(kind='barh', figsize=(10, 12))

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')
ax.set_title('Análise básica para cotação de equipamentos', fontsize=16)
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1.0), labelspacing=1.0, handletextpad=1.00, fontsize= 14)
